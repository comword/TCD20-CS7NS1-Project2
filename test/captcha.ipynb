# %%
from captcha.image import ImageCaptcha

# %%
generator = ImageCaptcha(width=128, height=64)

# %%
img = generator.generate_image('/|\\')
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x64 at 0x7FFB9A82FED0>

# %%
img.resize((200,100))
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7FFB9ACD7E90>

# %%
larg_gene = ImageCaptcha(width=200, height=100)

# %%
larg_gene.generate_image('/|\\')
