# %%
from captcha.image import ImageCaptcha

# %%
generator = ImageCaptcha(width=128, height=64)

# %%
img = generator.generate_image('c(´rr')
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x64 at 0x7FCF66427490>

# %%
img.resize((200,100))
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7FCF6643BBD0>

# %%
larg_gene = ImageCaptcha(width=200, height=100)

# %%
larg_gene.generate_image(',a.')
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7FCF66440410>
